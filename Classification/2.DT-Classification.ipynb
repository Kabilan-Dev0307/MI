# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Social_Network_Ads.csv")
df = pd.get_dummies(df, drop_first=True)
df.drop("User ID", axis=1, inplace=True )
df.head()
# Out:
#    Age  EstimatedSalary  Purchased  Gender_Male
# 0   19            19000          0         True
# 1   35            20000          0         True
# 2   26            43000          0        False
# 3   27            57000          0        False
# 4   19            76000          0         True

# %%
df["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
# Split Input and Output
x_values = df.iloc[:,df.columns != 'Purchased']
y_values = df.iloc[:,df.columns == 'Purchased']

# %%
# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_values, y_values, test_size=0.3, random_state=1)

# %%
# import decision tree model
from sklearn.tree import DecisionTreeClassifier as DT
model = DT()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# prediction
y_pred = model.predict(x_test)

# %%
# Import confusion matrix
from sklearn.metrics import confusion_matrix as cm
cm = cm(y_test, y_pred)
print(cm)
# Out:
# [[64  8]
#  [11 37]]

# %%
# Confusion Matrix Visualization
import seaborn as sns
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Report
from sklearn.metrics import classification_report as cr
report = cr(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        72
#            1       0.82      0.77      0.80        48
#
#     accuracy                           0.84       120
#    macro avg       0.84      0.83      0.83       120
# weighted avg       0.84      0.84      0.84       120

# %%
# Calculate all metrics for display in markdown cells
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Get confusion matrix breakdown
tn, fp, fn, tp = cm.ravel()

print(f"Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
print(f"Precision: {precision:.4f} ({precision*100:.2f}%)")
print(f"Recall: {recall:.4f} ({recall*100:.2f}%)")
print(f"F1-Score: {f1:.4f} ({f1*100:.2f}%)")
print(f"\nConfusion Matrix:")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives: {tp}")
# Out:
# Accuracy: 0.8417 (84.17%)
# Precision: 0.8222 (82.22%)
# Recall: 0.7708 (77.08%)
# F1-Score: 0.7957 (79.57%)
#
# Confusion Matrix:
# True Negatives: 64
# False Positives: 8
# False Negatives: 11
# True Positives: 37

# %% [markdown]
# ## Question: Overall, how often is the model correct?
#
# **Answer:** The model is correct **84.17%** of the time
#
# - **Accuracy Score: 0.8417**
# - This means out of 120 predictions, the model got 101 correct
# - The Decision Tree model performs well with an accuracy above 84%

# %% [markdown]
# ## Question: When the model predicts "Purchased", how often is it right?
#
# **Answer:** When the model predicts "Purchased", it's correct **82.22%** of the time
#
# - **Precision Score: 0.8222**
# - Out of 45 "Purchased" predictions, 37 were actually correct
# - This means 8 predictions were false positives (predicted purchase but didn't actually purchase)
# - The Decision Tree has good precision - it's quite reliable when it predicts a purchase

# %% [markdown]
# ## Question: Of all customers who actually purchased, how many did we catch?
#
# **Answer:** We correctly identified **77.08%** of customers who actually purchased
#
# - **Recall Score: 0.7708**
# - Out of 48 customers who actually purchased, we caught 37 of them
# - We missed 11 potential customers (false negatives)
# - The Decision Tree needs improvement in catching all purchasing customers

# %% [markdown]
# ## Question: What's the balanced score between precision and recall?
#
# **Answer:** The balanced F1-score is **79.57%**
#
# - **F1-Score: 0.7957**
# - This balances precision (82.22%) and recall (77.08%)
# - F1-score closer to 1 is better - our score of 0.80 is good
# - The Decision Tree shows a reasonable balance between precision and recall, though slightly favoring precision

# %% [markdown]
# ## Question: How many predictions were correct vs incorrect for each class?
#
# **Answer:** Confusion Matrix Breakdown:
#
# | Prediction Type | Count | Description |
# |---|---|---|
# | ✅ **True Negatives** | **64** | Correctly predicted "Not Purchased" |
# | ❌ **False Positives** | **8** | Incorrectly predicted "Purchased" |
# | ❌ **False Negatives** | **11** | Missed actual "Purchased" |
# | ✅ **True Positives** | **37** | Correctly predicted "Purchased" |
#
# **Summary:**
# - **Total Correct Predictions: 101** (64 + 37)
# - **Total Incorrect Predictions: 19** (8 + 11)
# - **Total Test Cases: 120**
#
# **Analysis:** The Decision Tree is better at avoiding false positives (8) than false negatives (11), showing it's more conservative in predicting purchases.

# %% [markdown]
# ## Question: How does Decision Tree compare to Random Forest?
#
# **Answer:** Decision Tree vs Random Forest Performance Comparison:
#
# | Metric | Decision Tree | Random Forest | Winner |
# |---|---|---|---|
# | **Accuracy** | 84.17% | 85.83% | 🏆 Random Forest |
# | **Precision** | 82.22% | 77.19% | 🏆 Decision Tree |
# | **Recall** | 77.08% | 91.67% | 🏆 Random Forest |
# | **F1-Score** | 79.57% | 83.81% | 🏆 Random Forest |
#
# **Key Insights:**
# - **Random Forest** is better overall with higher accuracy, recall, and F1-score
# - **Decision Tree** has better precision (fewer false positives)
# - **Random Forest** catches more actual buyers (higher recall)
# - **Random Forest** is more balanced and robust due to ensemble learning

# %%
print("="*50)
print("METHOD 1: DIRECT INPUT")
print("="*50)
# Direct input (change these values to test different scenarios)
age = 35
gender = "M"  # "M" for Male, "F" for Female
salary = 50000

print(f"\nTesting with: Age={age}, Gender={gender}, Salary=${salary:,}")

# Uncomment the lines below if you want to use interactive input:
# age = int(input("Enter Age: "))
# gender = input("Enter Gender (M / F): ")
# salary = int(input("Enter Estimated Salary: "))
# Out:
# ==================================================
# METHOD 1: DIRECT INPUT
# ==================================================
#
# Testing with: Age=35, Gender=M, Salary=$50,000

# %%
# Preprocess input value of gender to 0 and 1
if gender.upper() == 'M':
    gender_encoded = 1  # Male = 1
else:
    gender_encoded = 0  # Female = 0

# Create input array for prediction
user_input = [[age, salary, gender_encoded]]

# Make prediction
prediction = model.predict(user_input)
prediction_proba = model.predict_proba(user_input)

# Display result
if prediction[0] == 1:
    result = "Will Purchase"
    confidence = prediction_proba[0][1] * 100
else:
    result = "Will Not Purchase"
    confidence = prediction_proba[0][0] * 100

print(f"\n=== Decision Tree Prediction ===")
print(f"Customer Profile: {age} years old, {gender}, ${salary:,} salary")
print(f"Prediction: {result}")
print(f"Confidence: {confidence:.2f}%")

# Show probability breakdown
print(f"\nProbability Breakdown:")
print(f"  Will NOT Purchase: {prediction_proba[0][0]*100:.2f}%")
print(f"  Will Purchase: {prediction_proba[0][1]*100:.2f}%")
# Out:
# === Decision Tree Prediction ===
# Customer Profile: 35 years old, M, $50,000 salary
# Prediction: Will Not Purchase
# Confidence: 100.00%
#
# Probability Breakdown:
#   Will NOT Purchase: 100.00%
#   Will Purchase: 0.00%
# c:\Users\a-kjayar01\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\a-kjayar01\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# Test with multiple scenarios
print("\n" + "="*50)
print("TESTING MULTIPLE SCENARIOS")
print("="*50)

test_cases = [
    {"age": 25, "gender": "F", "salary": 30000, "description": "Young female, low salary"},
    {"age": 35, "gender": "M", "salary": 80000, "description": "Middle-aged male, high salary"},
    {"age": 45, "gender": "F", "salary": 60000, "description": "Older female, medium salary"},
    {"age": 22, "gender": "M", "salary": 25000, "description": "Young male, low salary"},
    {"age": 40, "gender": "M", "salary": 90000, "description": "Mature male, high salary"}
]

for i, case in enumerate(test_cases, 1):
    # Encode gender
    gender_enc = 1 if case["gender"] == "M" else 0
    
    # Make prediction
    user_data = [[case["age"], case["salary"], gender_enc]]
    pred = model.predict(user_data)
    pred_prob = model.predict_proba(user_data)
    
    # Determine result
    result = "Will Purchase" if pred[0] == 1 else "Will Not Purchase"
    confidence = pred_prob[0][1]*100 if pred[0] == 1 else pred_prob[0][0]*100
    
    print(f"\nTest {i}: {case['description']}")
    print(f"  Profile: {case['age']} years, {case['gender']}, ${case['salary']:,}")
    print(f"  Prediction: {result} ({confidence:.1f}% confidence)")
