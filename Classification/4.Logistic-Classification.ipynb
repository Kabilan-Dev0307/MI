# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Social_Network_Ads.csv")
df = pd.get_dummies(df, drop_first=True)
df.drop("User ID", axis=1, inplace=True )
df.head()
# Out:
#    Age  EstimatedSalary  Purchased  Gender_Male
# 0   19            19000          0         True
# 1   35            20000          0         True
# 2   26            43000          0        False
# 3   27            57000          0        False
# 4   19            76000          0         True

# %%
df["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
# Split Input and Output
x_values = df.iloc[:,df.columns != 'Purchased']
y_values = df.iloc[:,df.columns == 'Purchased']

# %%
# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_values, y_values, test_size=0.3, random_state=1)

# %%
# import decision tree model
from sklearn.linear_model import LogisticRegression as LR
model = LR()
model.fit(x_train, y_train)
# Out:
# c:\Users\a-kjayar01\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\a-kjayar01\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# prediction
y_pred = model.predict(x_test)

# %%
# Import confusion matrix
from sklearn.metrics import confusion_matrix as cm
cm = cm(y_test, y_pred)
print(cm)
# Out:
# [[63  9]
#  [14 34]]

# %%
# Confusion Matrix Visualization
import seaborn as sns
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Report
from sklearn.metrics import classification_report as cr
report = cr(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85        72
#            1       0.79      0.71      0.75        48
#
#     accuracy                           0.81       120
#    macro avg       0.80      0.79      0.80       120
# weighted avg       0.81      0.81      0.81       120

# %%
# Calculate all metrics for display in markdown cells
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Get confusion matrix breakdown
tn, fp, fn, tp = cm.ravel()

print(f"Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
print(f"Precision: {precision:.4f} ({precision*100:.2f}%)")
print(f"Recall: {recall:.4f} ({recall*100:.2f}%)")
print(f"F1-Score: {f1:.4f} ({f1*100:.2f}%)")
print(f"\nConfusion Matrix:")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives: {tp}")
# Out:
# Accuracy: 0.8083 (80.83%)
# Precision: 0.7907 (79.07%)
# Recall: 0.7083 (70.83%)
# F1-Score: 0.7473 (74.73%)
#
# Confusion Matrix:
# True Negatives: 63
# False Positives: 9
# False Negatives: 14
# True Positives: 34

# %% [markdown]
# ## Question: Overall, how often is the model correct?
#
# **Answer:** The model is correct **80.83%** of the time
#
# - **Accuracy Score: 0.8083**
# - This means out of 120 predictions, the model got 97 correct
# - The Logistic Regression model performs well with an accuracy above 80%

# %% [markdown]
# ## Question: When the model predicts "Purchased", how often is it right?
#
# **Answer:** When the model predicts "Purchased", it's correct **79.07%** of the time
#
# - **Precision Score: 0.7907**
# - Out of 43 "Purchased" predictions, 34 were actually correct
# - This means 9 predictions were false positives (predicted purchase but didn't actually purchase)
# - The Logistic Regression has good precision - it's quite reliable when it predicts a purchase

# %% [markdown]
# ## Question: Of all customers who actually purchased, how many did we catch?
#
# **Answer:** We correctly identified **70.83%** of customers who actually purchased
#
# - **Recall Score: 0.7083**
# - Out of 48 customers who actually purchased, we caught 34 of them
# - We missed 14 potential customers (false negatives)
# - The Logistic Regression needs improvement in catching all purchasing customers

# %% [markdown]
# ## Question: What's the balanced score between precision and recall?
#
# **Answer:** The balanced F1-score is **74.73%**
#
# - **F1-Score: 0.7473**
# - This balances precision (79.07%) and recall (70.83%)
# - F1-score closer to 1 is better - our score of 0.75 is good
# - The Logistic Regression shows a reasonable balance between precision and recall, though slightly favoring precision

# %% [markdown]
# ## Question: How many predictions were correct vs incorrect for each class?
#
# **Answer:** Confusion Matrix Breakdown:
#
# | Prediction Type | Count | Description |
# |---|---|---|
# | ✅ **True Negatives** | **63** | Correctly predicted "Not Purchased" |
# | ❌ **False Positives** | **9** | Incorrectly predicted "Purchased" |
# | ❌ **False Negatives** | **14** | Missed actual "Purchased" |
# | ✅ **True Positives** | **34** | Correctly predicted "Purchased" |
#
# **Summary:**
# - **Total Correct Predictions: 97** (63 + 34)
# - **Total Incorrect Predictions: 23** (9 + 14)
# - **Total Test Cases: 120**
#
# **Analysis:** The Logistic Regression is better at avoiding false positives (9) compared to false negatives (14), showing it's more conservative in predicting purchases.

# %% [markdown]
# ## Question: How does Logistic Regression compare to other models?
#
# **Answer:** Logistic Regression vs Other Models Performance Comparison:
#
# | Metric | Logistic Regression | Decision Tree | Random Forest | SVM | Best Model |
# |---|---|---|---|---|---|
# | **Accuracy** | 80.83% | 84.17% | 85.83% | 66.67% | 🏆 Random Forest |
# | **Precision** | 79.07% | 82.22% | 77.19% | 66.67% | 🏆 Decision Tree |
# | **Recall** | 70.83% | 77.08% | 91.67% | 33.33% | 🏆 Random Forest |
# | **F1-Score** | 74.73% | 79.57% | 83.81% | 44.44% | 🏆 Random Forest |
#
# **Key Insights:**
# - **Random Forest** is the best overall performer across most metrics
# - **Logistic Regression** ranks 3rd overall, performing better than SVM but worse than tree-based models
# - **Logistic Regression** has good interpretability and balanced performance
# - **SVM** performs worst with this dataset configuration

# %%
print("="*50)
print("METHOD 1: DIRECT INPUT")
print("="*50)
# Direct input (change these values to test different scenarios)
age = 35
gender = "M"  # "M" for Male, "F" for Female
salary = 50000

print(f"\nTesting with: Age={age}, Gender={gender}, Salary=${salary:,}")

# Uncomment the lines below if you want to use interactive input:
# age = int(input("Enter Age: "))
# gender = input("Enter Gender (M / F): ")
# salary = int(input("Enter Estimated Salary: "))
# Out:
# ...
# METHOD 1: DIRECT INPUT
# ...
#
# Testing with: Age=35, Gender=M, Salary=$50,000

# %%
# Preprocess input value of gender to 0 and 1
if gender.upper() == 'M':
    gender_encoded = 1  # Male = 1
else:
    gender_encoded = 0  # Female = 0

# Create input array for prediction
user_input = [[age, salary, gender_encoded]]

# Make prediction
prediction = model.predict(user_input)
prediction_proba = model.predict_proba(user_input)

# Display result
if prediction[0] == 1:
    result = "Will Purchase"
    confidence = prediction_proba[0][1] * 100
else:
    result = "Will Not Purchase"
    confidence = prediction_proba[0][0] * 100

print(f"\n=== Logistic Regression Prediction ===")
print(f"Customer Profile: {age} years old, {gender}, ${salary:,} salary")
print(f"Prediction: {result}")
print(f"Confidence: {confidence:.2f}%")

# Show probability breakdown
print(f"\nProbability Breakdown:")
print(f"  Will NOT Purchase: {prediction_proba[0][0]*100:.2f}%")
print(f"  Will Purchase: {prediction_proba[0][1]*100:.2f}%")
# Out:
# === Logistic Regression Prediction ===
# Customer Profile: 35 years old, M, $50,000 salary
# Prediction: Will Not Purchase
# Confidence: 93.37%
#
# Probability Breakdown:
#   Will NOT Purchase: 93.37%
#   Will Purchase: 6.63%
# c:\Users\a-kjayar01\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\a-kjayar01\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# Test with multiple scenarios
print("\n" + "="*50)
print("TESTING MULTIPLE SCENARIOS")
print("="*50)

test_cases = [
    {"age": 25, "gender": "F", "salary": 30000, "description": "Young female, low salary"},
    {"age": 35, "gender": "M", "salary": 80000, "description": "Middle-aged male, high salary"},
    {"age": 45, "gender": "F", "salary": 60000, "description": "Older female, medium salary"},
    {"age": 22, "gender": "M", "salary": 25000, "description": "Young male, low salary"},
    {"age": 40, "gender": "M", "salary": 90000, "description": "Mature male, high salary"}
]

for i, case in enumerate(test_cases, 1):
    # Encode gender
    gender_enc = 1 if case["gender"] == "M" else 0
    
    # Make prediction
    user_data = [[case["age"], case["salary"], gender_enc]]
    pred = model.predict(user_data)
    pred_prob = model.predict_proba(user_data)
    
    # Determine result
    result = "Will Purchase" if pred[0] == 1 else "Will Not Purchase"
    confidence = pred_prob[0][1]*100 if pred[0] == 1 else pred_prob[0][0]*100
    
    print(f"\nTest {i}: {case['description']}")
    print(f"  Profile: {case['age']} years, {case['gender']}, ${case['salary']:,}")
    print(f"  Prediction: {result} ({confidence:.1f}% confidence)")
# Out:
# ...
# TESTING MULTIPLE SCENARIOS
# ...
#
# Test 1: Young female, low salary
#   Profile: 25 years, F, $30,000
#   Prediction: Will Not Purchase (99.9% confidence)
#
# Test 2: Middle-aged male, high salary
#   Profile: 35 years, M, $80,000
#   Prediction: Will Not Purchase (76.9% confidence)
#
# Test 3: Older female, medium salary
#   Profile: 45 years, F, $60,000
#   Prediction: Will Not Purchase (50.3% confidence)
#
# Test 4: Young male, low salary
#   Profile: 22 years, M, $25,000
#   Prediction: Will Not Purchase (99.9% confidence)
#
# Test 5: Mature male, high salary
#   Profile: 40 years, M, $90,000
#   Prediction: Will Purchase (64.2% confidence)
# c:\Users\a-kjayar01\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ...
